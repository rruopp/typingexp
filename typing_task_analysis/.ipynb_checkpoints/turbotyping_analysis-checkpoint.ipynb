# %%
## Script to analyze Turbo Typing data

# %%
import os
import numpy as np
import pandas as pd
import math
import glob

# %%
# Setting save directory
save_dir = os.getcwd()
save_dir
# Out:
# '/Users/rubi/Desktop/Github/typingexp/typing_task_analysis'

# %%
# Getting subject data folders from server
server = r'/Volumes/greenhouse/typingtask_data/subject_data'
os.chdir(server)
folders = os.listdir()

# Looping through subject folders, getting appropriate paths to data, 
# and making sID list
sub_folders = list(filter(lambda x: x.startswith('s', 0, 1), folders))
all_turbo = pd.DataFrame()
ID_list = []
for sub in sub_folders:
    sub_folder = r'/Volumes/greenhouse/typingtask_data/'\
                 'subject_data/%s/turbotyping_data' % sub
    os.chdir(sub_folder)
    sID = sub.split('_', 1)[0]
    turbo = pd.read_csv(glob.glob('*_datafile.tsv')[0], sep='\t')
    all_turbo = pd.concat([all_turbo, turbo])
    ID_list.append(sID)

# %%
all_turbo
# Out:
#    participantID  trialNumber  \
# 0            262           -2
# 1            262           -1
# 2            262            0
# 3            262            1
# 4            262            2
# ..           ...          ...
# 12          s305           10
# 13          s305           11
# 14          s305           12
# 15          s305           13
# 16          s305           14
#
#                                       currentSentence  \
# 0               Looking for some gift hints from you.
# 1              I can't tell you when they'll be back.
# 2           Our forces are ready to come immediately.
# 3      A bad thing has been turned into a good thing.
# 4          Do you want to eat lunch somewhere before?
# ..                                                ...
# 12     A bad thing has been turned into a good thing.
# 13          Our forces are ready to come immediately.
# 14        Sunday tickets have been on sale for weeks.
# 15           I will need to have my memory refreshed.
# 16  Let me know if there are any other problems wi...
#
#                                         typedSentence            trialStart  \
# 0               Looking for some gift hints from you.  1/23/2024 9:17:58 AM
# 1              I can't tell you when they'll be back.  1/23/2024 9:18:28 AM
# 2           Our forces are ready to come immedaitely.  1/23/2024 9:19:04 AM
# 3      A bad thing has been turned into a good thing.  1/23/2024 9:19:12 AM
# 4          Do you want to eat lunch somewhere before?  1/23/2024 9:19:19 AM
# ..                                                ...                   ...
# 12     A bad thing has been turned into a good thing.  7/11/2024 7:09:58 PM
# 13           Our forces are ready to come immediately  7/11/2024 7:10:06 PM
# 14        Sunday tickets have been on sale for weeks.  7/11/2024 7:10:16 PM
# 15           I will need to have my memory refreshed.  7/11/2024 7:10:22 PM
# 16  Let me know if there are any other problems wi...  7/11/2024 7:10:29 PM
#
#     wpm  accuracy                                           timeData  \
# 0    86       100  21454, 21906, 22156, 22284, 22371, 22611, 2262...
# 1    63       100  22442, 22633, 22968, 23041, 23498, 23809, 2394...
# 2    80        95  927, 1118, 1311, 1494, 1631, 1718, 1854, 1903,...
# 3   108       100  586, 857, 970, 1146, 1281, 1346, 1458, 1554, 1...
# 4    98       100  530, 730, 858, 962, 1065, 1130, 1194, 1266, 13...
# ..  ...       ...                                                ...
# 12   90       100  617, 840, 945, 1113, 1233, 1321, 1409, 1505, 1...
# 13   67        98  570, 722, 834, 986, 1034, 1154, 1235, 1355, 15...
# 14  101       100  490, 802, 898, 1067, 1107, 1203, 1322, 1386, 1...
# 15   94       100  371, 523, 642, 754, 803, 883, 1019, 1091, 1195...
# 16  106       100  449, 609, 737, 833, 880, 1017, 1105, 1656, 180...
#
#                                               keyData  \
# 0   LeftShift, L, O, O, K, I, N, G, Space, F, O, R...
# 1   LeftShift, I, C, A, Backspace, Backspace, Spac...
# 2   LeftShift, LeftShift, O, U, R, Space, F, O, R,...
# 3   LeftShift, A, Space, B, A, D, Space, T, H, I, ...
# 4   LeftShift, D, O, Space, Y, O, U, Space, W, A, ...
# ..                                                ...
# 12  LeftShift, A, Space, B, A, D, Space, T, H, I, ...
# 13  LeftShift, O, U, R, Space, F, O, R, C, E, S, S...
# 14  LeftShift, S, U, N, D, A, Y, Space, T, I, C, K...
# 15  LeftShift, I, Space, W, I, L, L, Space, N, E, ...
# 16  LeftShift, L, E, T, Space, M, E, Space, K, N, ...
#
#                                      keyDataConverted  \
# 0   LeftShift, L, o, o, k, i, n, g,  , f, o, r,  ,...
# 1   LeftShift, I, c, a, Backspace, Backspace,  , c...
# 2   LeftShift, LeftShift, O, u, r,  , f, o, r, c, ...
# 3   LeftShift, A,  , b, a, d,  , t, h, i, n, g,  ,...
# 4   LeftShift, D, o,  , y, o, u,  , w, a, n, t,  ,...
# ..                                                ...
# 12  LeftShift, A,  , b, a, d,  , t, h, i, n, g,  ,...
# 13  LeftShift, O, u, r,  , f, o, r, c, e, s,  , a,...
# 14  LeftShift, S, u, n, d, a, y,  , t, i, c, k, e,...
# 15  LeftShift, I,  , w, i, l, l,  , n, e, e, d,  ,...
# 16  LeftShift, L, e, t,  , m, e,  , k, n, o, w,  ,...
#
#                                            timeDataUp  \
# 0   22043, 22051, 22220, 22411, 22500, 22691, 2277...
# 1   22769, 22825, 23081, 23131, 23562, 23890, 2407...
# 2   1071, 1470, 1478, 1655, 1758, 1846, 1926, 1998...
# 3   962, 994, 1066, 1211, 1402, 1449, 1601, 1681, ...
# 4   802, 841, 946, 1114, 1186, 1234, 1313, 1394, 1...
# ..                                                ...
# 12  897, 953, 1040, 1201, 1336, 1409, 1513, 1601, ...
# 13  762, 882, 929, 1058, 1145, 1250, 1362, 1426, 1...
# 14  859, 906, 970, 1147, 1211, 1306, 1443, 1491, 1...
# 15  571, 610, 746, 851, 939, 955, 1107, 1187, 1284...
# 16  649, 705, 833, 937, 977, 1073, 1201, 1769, 195...
#
#                                             keyDataUp
# 0   L, LeftShift, O, O, K, I, N, G, Space, F, O, R...
# 1   I, LeftShift, C, A, Backspace, Backspace, Spac...
# 2   LeftShift, LeftShift, O, U, R, Space, F, O, R,...
# 3   LeftShift, A, Space, B, A, D, Space, T, H, I, ...
# 4   LeftShift, D, O, Space, Y, O, U, Space, W, A, ...
# ..                                                ...
# 12  LeftShift, A, Space, B, A, D, Space, T, H, I, ...
# 13  LeftShift, O, U, R, Space, F, O, R, C, E, S, S...
# 14  LeftShift, S, U, N, D, A, Y, Space, T, I, C, K...
# 15  LeftShift, I, Space, W, I, L, L, Space, N, E, ...
# 16  LeftShift, L, E, T, Space, M, E, Space, K, N, ...
#
# [357 rows x 12 columns]

# %%
# stripped_keys_1 = ((df['key_resp_1.keys'].str.strip('[,]')).dropna()).str.split(',', expand = True)
stripped_times = ((all_turbo['timeData'].str.strip('[,]')).dropna()).str.split(',', expand = True)
stripped_times
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0   21454   21906   22156   22284   22371   22611   22628   22748   22827
# 1   22442   22633   22968   23041   23498   23809   23945   24049   24106
# 2     927    1118    1311    1494    1631    1718    1854    1903    2006
# 3     586     857     970    1146    1281    1346    1458    1554    1634
# 4     530     730     858     962    1065    1130    1194    1266    1361
# ..    ...     ...     ...     ...     ...     ...     ...     ...     ...
# 12    617     840     945    1113    1233    1321    1409    1505    1577
# 13    570     722     834     986    1034    1154    1235    1355    1571
# 14    490     802     898    1067    1107    1203    1322    1386    1482
# 15    371     523     642     754     803     883    1019    1091    1195
# 16    449     609     737     833     880    1017    1105    1656    1809
#
#         9   ...    78    79    80    81    82    83    84    85    86    87
# 0    22956  ...  None  None  None  None  None  None  None  None  None  None
# 1    24241  ...  None  None  None  None  None  None  None  None  None  None
# 2     2198  ...  None  None  None  None  None  None  None  None  None  None
# 3     1706  ...  None  None  None  None  None  None  None  None  None  None
# 4     1426  ...  None  None  None  None  None  None  None  None  None  None
# ..     ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 12    1681  ...  None  None  None  None  None  None  None  None  None  None
# 13    1626  ...  None  None  None  None  None  None  None  None  None  None
# 14    1587  ...  None  None  None  None  None  None  None  None  None  None
# 15    1259  ...  None  None  None  None  None  None  None  None  None  None
# 16    1929  ...  None  None  None  None  None  None  None  None  None  None
#
# [357 rows x 88 columns]
